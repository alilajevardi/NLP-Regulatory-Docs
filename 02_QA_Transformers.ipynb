# %% [markdown]
# # Answering date questions by using SOTA BERT through simple transformers

# %%
import torch
import json
import os
import pandas as pd
from datetime import datetime
from simpletransformers.question_answering import QuestionAnsweringModel

# %%
# Intiate usage of GPU for training

print(torch.__version__)

cuda_available = torch.cuda.is_available()

# If there's a GPU available...
if cuda_available:    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")

# %% [markdown]
# ## Fine-tuning of pre-trained BERT for QA process using SQuAD 2.0 dataset

# %%
with open('./data/train-v2.0.json', 'r') as f:
    train_data = json.load(f)


train_data = [item for topic in train_data['data'] for item in topic['paragraphs']]

# %%
# define the model


train_args = {
    'learning_rate': 3e-5,
    'optimizer': 'AdamW',
    'adam_epsilon': 1e-8,
    'manual_seed': 101,
    'num_train_epochs': 2,
    'max_seq_length': 384, #Maximum sequence length the model will support
    'doc_stride': 128, # splitting up a long document into chunks, how much stride to take between chunks.
    'reprocess_input_data': False,
    'train_batch_size': 2,
    'gradient_accumulation_steps': 8,
    'fp16': False, #True --> fp16 mode requires NVidia Apex library
    'overwrite_output_dir':True,  #If True, the trained model will be saved (overwrite) to the ouput_dir= './outputs/'
    'save_steps': 2000, # Save a model checkpoint at every 2000 steps. Set to -1 to disable.
    'tensorboard_dir': False, # Tensorboard events will be saved in a subfolder inside runs/ like runs/Dec02_09-32-58_36d9e58955b0/
}

model = QuestionAnsweringModel('bert', 'bert-base-cased', use_cuda=True, cuda_device=-1, args=train_args)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForQuestionAnswering: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.train_model(train_data)
# Out:
# convert squad examples to features: 100%|██████████| 130319/130319 [00:37<00:00, 3499.84it/s]
# add example index and unique id: 100%|██████████| 130319/130319 [00:00<00:00, 1076867.54it/s]
# Epoch:   0%|          | 0/3 [00:00<?, ?it/s]
# Running Epoch 0 of 3:   0%|          | 0/16457 [00:00<?, ?it/s]
# Running Epoch 1 of 3:   0%|          | 0/16457 [00:00<?, ?it/s]
# Running Epoch 2 of 3:   0%|          | 0/16457 [00:00<?, ?it/s]
# (49371, 0.7569055093715983)

# %% [markdown]
# ## Evaluation of model performance on SQuAD 2.0 database

# %%
with open('data/dev-v2.0.json', 'r') as f:
    dev_data = json.load(f)

dev_data = [item for topic in dev_data['data'] for item in topic['paragraphs'] ]

preds, probs = model.predict(dev_data)

os.makedirs('results', exist_ok=True)
# Out:
# convert squad examples to features: 100%|██████████| 11873/11873 [00:05<00:00, 2305.88it/s]
# add example index and unique id: 100%|██████████| 11873/11873 [00:00<00:00, 735474.40it/s]
# Running Prediction:   0%|          | 0/1513 [00:00<?, ?it/s]

# %%
# save results of evaluation
submission = dict()
submission = {pred['id']: pred['answer'] for pred in preds}

    
with open('results/submission.json', 'w') as f:
    json.dump(submission, f)

# %% [markdown]
# ## Import provided Reg data

# %%
# Read JSON file that include transformed reg data for QA classifier
with open('sample_data.json') as data_file:
    data_loaded = json.load(data_file)
    
    
pred_data = [item for topic in data_loaded['data'] for item in topic['paragraphs'] ]

# %% [markdown]
# ## Capturing dates via QA prediction

# %%
predictions, raw_outputs = model.predict(pred_data, n_best_size=1)
# Out:
# convert squad examples to features: 100%|██████████| 294/294 [01:17<00:00,  3.79it/s]
# add example index and unique id: 100%|██████████| 294/294 [00:00<00:00, 63169.17it/s]
# Running Prediction:   0%|          | 0/871 [00:00<?, ?it/s]

# %%
pred_df = pd.DataFrame(predictions)
prob_df = pd.DataFrame(raw_outputs)

# %%
pred_df.head(10)
prob_df.head(10)
# Out:
#                                        id               probability
# 0  9841051B-7A7F-4657-98A9-117A9B36C98B_1      [0.9994059361548607]
# 1  9841051B-7A7F-4657-98A9-117A9B36C98B_2       [0.997699414515289]
# 2  9841051B-7A7F-4657-98A9-117A9B36C98B_3      [0.9999995664582505]
# 3  9841051B-7A7F-4657-98A9-117A9B36C98B_4      [0.9996517625834309]
# 4  9841051B-7A7F-4657-98A9-117A9B36C98B_5     [0.15003815075635676]
# 5  9841051B-7A7F-4657-98A9-117A9B36C98B_6   [3.744063148752484e-05]
# 6  C5FE84B7-E3B1-4677-8EDF-A60E7D358055_1  [4.9066822113834034e-05]
# 7  C5FE84B7-E3B1-4677-8EDF-A60E7D358055_2   [0.0004096146249521647]
# 8  C5FE84B7-E3B1-4677-8EDF-A60E7D358055_3      [0.8459255957363234]
# 9  C5FE84B7-E3B1-4677-8EDF-A60E7D358055_4   [0.0010002256285069012]

# %% [markdown]
# ## Function to change captured dates to requested dd/mm/YYYY format

# %%
def get_date(s_date):
    date_patterns = ["%d-%m-%Y", "%Y-%m-%d", "%B %d, %Y", "%B %Y", "%b. %d, %Y", "%A, %B %d, %Y"]

    for pattern in date_patterns:
        try:
            return datetime.strptime(s_date, pattern).strftime('%d/%m/%Y')
        except:
              pass #return s_date

    #print("Date is not in expected format: %s" %(s_date))

# %% [markdown]
# ## Processing date prediction outcomes to comply with provided reg data

# %%
output_df = pred_df
output_df['UID'] = ''
output_df['Q'] = ''
output_df['Probability'] = prob_df['probability']


for index, row in output_df.iterrows():
    idx = row['id'].split('_')
    row['UID'] = idx[0]
    if idx[1] == '1':
        row['Q'] = 'Publiccation/ Issue Date'
    elif idx[1] == '2':
        row['Q'] = 'Compliance Date'
    elif idx[1] == '3':
        row['Q'] = 'Effective Date'
    elif idx[1] == '4':
        row['Q'] = 'Repeal Date'
    elif idx[1] == '5':
        row['Q'] = 'Consultation Period'
    else:
        row['Q'] = 'Issuing Department'
    
    row['answer'] = row['answer'][0]
    if row['answer'] == 'empty':
        row['answer'] = 'Unknown'
    else:
        row['answer'] = get_date(row['answer'])
        
    row['Probability'] = float(row['Probability'][0])
    
output_df.drop(columns=['id'])

output_df = output_df[['UID', 'Q', 'answer', 'Probability']]
output_df.columns = ['UID', 'Queston', 'Insight', 'Probability']

# %%
output_df.head(50)
# Out:
#                                      UID                   Queston  \
# 0   9841051B-7A7F-4657-98A9-117A9B36C98B  Publiccation/ Issue Date
# 1   9841051B-7A7F-4657-98A9-117A9B36C98B           Compliance Date
# 2   9841051B-7A7F-4657-98A9-117A9B36C98B            Effective Date
# 3   9841051B-7A7F-4657-98A9-117A9B36C98B               Repeal Date
# 4   9841051B-7A7F-4657-98A9-117A9B36C98B       Consultation Period
# 5   9841051B-7A7F-4657-98A9-117A9B36C98B        Issuing Department
# 6   C5FE84B7-E3B1-4677-8EDF-A60E7D358055  Publiccation/ Issue Date
# 7   C5FE84B7-E3B1-4677-8EDF-A60E7D358055           Compliance Date
# 8   C5FE84B7-E3B1-4677-8EDF-A60E7D358055            Effective Date
# 9   C5FE84B7-E3B1-4677-8EDF-A60E7D358055               Repeal Date
# 10  C5FE84B7-E3B1-4677-8EDF-A60E7D358055       Consultation Period
# 11  C5FE84B7-E3B1-4677-8EDF-A60E7D358055        Issuing Department
# 12  6DC38C33-FB75-4025-8D1E-C3F708E67E67  Publiccation/ Issue Date
# 13  6DC38C33-FB75-4025-8D1E-C3F708E67E67           Compliance Date
# 14  6DC38C33-FB75-4025-8D1E-C3F708E67E67            Effective Date
# 15  6DC38C33-FB75-4025-8D1E-C3F708E67E67               Repeal Date
# 16  6DC38C33-FB75-4025-8D1E-C3F708E67E67       Consultation Period
# 17  6DC38C33-FB75-4025-8D1E-C3F708E67E67        Issuing Department
# 18  0EAAA615-87DB-4600-9A1F-507D6A7C1EBB  Publiccation/ Issue Date
# 19  0EAAA615-87DB-4600-9A1F-507D6A7C1EBB           Compliance Date
# 20  0EAAA615-87DB-4600-9A1F-507D6A7C1EBB            Effective Date
# 21  0EAAA615-87DB-4600-9A1F-507D6A7C1EBB               Repeal Date
# 22  0EAAA615-87DB-4600-9A1F-507D6A7C1EBB       Consultation Period
# 23  0EAAA615-87DB-4600-9A1F-507D6A7C1EBB        Issuing Department
# 24  9155D9E6-4B38-443B-B43E-586431AC5251  Publiccation/ Issue Date
# 25  9155D9E6-4B38-443B-B43E-586431AC5251           Compliance Date
# 26  9155D9E6-4B38-443B-B43E-586431AC5251            Effective Date
# 27  9155D9E6-4B38-443B-B43E-586431AC5251               Repeal Date
# 28  9155D9E6-4B38-443B-B43E-586431AC5251       Consultation Period
# 29  9155D9E6-4B38-443B-B43E-586431AC5251        Issuing Department
# 30  76DBF3CB-63AC-49D9-9119-509F00E10577  Publiccation/ Issue Date
# 31  76DBF3CB-63AC-49D9-9119-509F00E10577           Compliance Date
# 32  76DBF3CB-63AC-49D9-9119-509F00E10577            Effective Date
# 33  76DBF3CB-63AC-49D9-9119-509F00E10577               Repeal Date
# 34  76DBF3CB-63AC-49D9-9119-509F00E10577       Consultation Period
# 35  76DBF3CB-63AC-49D9-9119-509F00E10577        Issuing Department
# 36  3104063D-83E8-4794-8531-5AD0A77C1C6A  Publiccation/ Issue Date
# 37  3104063D-83E8-4794-8531-5AD0A77C1C6A           Compliance Date
# 38  3104063D-83E8-4794-8531-5AD0A77C1C6A            Effective Date
# 39  3104063D-83E8-4794-8531-5AD0A77C1C6A               Repeal Date
# 40  3104063D-83E8-4794-8531-5AD0A77C1C6A       Consultation Period
# 41  3104063D-83E8-4794-8531-5AD0A77C1C6A        Issuing Department
# 42  04C47556-79AD-4AC7-B766-BAB5A76F1DB9  Publiccation/ Issue Date
# 43  04C47556-79AD-4AC7-B766-BAB5A76F1DB9           Compliance Date
# 44  04C47556-79AD-4AC7-B766-BAB5A76F1DB9            Effective Date
# 45  04C47556-79AD-4AC7-B766-BAB5A76F1DB9               Repeal Date
# 46  04C47556-79AD-4AC7-B766-BAB5A76F1DB9       Consultation Period
# 47  04C47556-79AD-4AC7-B766-BAB5A76F1DB9        Issuing Department
# 48  2879E818-6B43-4150-8DCC-CA283DB531AE  Publiccation/ Issue Date
# 49  2879E818-6B43-4150-8DCC-CA283DB531AE           Compliance Date
#
#        Insight Probability
# 0   15/03/2021    0.999406
# 1   15/03/2021    0.997699
# 2   15/03/2021         1.0
# 3   15/03/2021    0.999652
# 4      Unknown    0.150038
# 5      Unknown    0.000037
# 6      Unknown    0.000049
# 7      Unknown     0.00041
# 8   19/01/2021    0.845926
# 9      Unknown       0.001
# 10     Unknown    0.000758
# 11     Unknown    0.000007
# 12     Unknown    0.000017
# 13     Unknown    0.000368
# 14     Unknown    0.011868
# 15     Unknown    0.000624
# 16     Unknown    0.002761
# 17     Unknown    0.000118
# 18     Unknown     0.00001
# 19     Unknown    0.000729
# 20     Unknown    0.105967
# 21     Unknown    0.000478
# 22     Unknown    0.010862
# 23     Unknown    0.002173
# 24     Unknown    0.000052
# 25     Unknown    0.089621
# 26     Unknown    0.861974
# 27     Unknown    0.739301
# 28     Unknown    0.006327
# 29     Unknown    0.000021
# 30     Unknown    0.002503
# 31     Unknown    0.006852
# 32  25/11/2020     0.99961
# 33  25/11/2020    0.999912
# 34     Unknown    0.001324
# 35     Unknown     0.00005
# 36  14/12/2020    0.999695
# 37  14/12/2020    0.999929
# 38  14/12/2020    0.999994
# 39  14/12/2020         1.0
# 40     Unknown    0.230546
# 41     Unknown     0.00544
# 42  14/12/2020    0.999695
# 43  14/12/2020    0.999929
# 44  14/12/2020    0.999994
# 45  14/12/2020         1.0
# 46     Unknown    0.230546
# 47     Unknown     0.00544
# 48  21/06/1995    0.744584
# 49     Unknown    0.043215

# %% [markdown]
# ### END
